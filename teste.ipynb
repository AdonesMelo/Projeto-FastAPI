# %%
import requests

headers = {
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI0IiwiZXhwIjoxNzUwMjA2Mzg3fQ.91qc-zJqFG4irFBq-LYpiQjmEVOgsi6NLkdXJHbehuQ"
}

requisicao = requests.get("http://127.0.0.1:8000/auth/refresh", headers=headers)
print(requisicao)
print(requisicao.json())
# Out:
# <Response [200]>
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiI0IiwiZXhwIjoxNzQ5NjA0MzIwfQ.lmnz0RI3scCprSZ2bnLFrCWUL2TdUbIsinFZNQdtobc', 'token_type': 'Bearer'}
